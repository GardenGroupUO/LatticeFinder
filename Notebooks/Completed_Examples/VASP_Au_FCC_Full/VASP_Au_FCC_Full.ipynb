# %% [markdown]
# # An example for obtaining the lattice constants of a crystal system with 1 lattice constants using LatticeFinder with VASP Calculations

# %% [markdown]
# [Back To Table of Contents](../../LatticeFinder_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will be obtaining the lattice constant of a Au face centred cubic (FCC) crystal structure using VASP with the PBE functional. Below we will show an example of the *Run_LatticeFinder.py* file use to run LatticeFinder, where all the data has been obtained in the ``lattice_data.txt`` file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the ``from LatticeFinder import LatticeFinder_Program`` execution cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run_LatticeFinder.py* file from beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above. Jupyter will display a box that will ask you if you want to restart the kernal. Press the <img src="../../Images/Restart_button.svg" alt="Restart_Button" width="50"/> button to run the full Jupyter notebook in Python.
#
# Note: These are the vanilla settings for running LatticeFinder on Au, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example from scratch, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run_LatticeFinder.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = [file for file in os.listdir('.') if not (file.endswith('.ipynb') or file.startswith('VASP_Files') or file.startswith('lattice_data.txt'))]
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# The *Run_LatticeFinder.py* code begins below:

# %% [markdown]
# ## A *Run_LatticeFinder.py* script for running LatticeFinder on an FCC crystal structure with VASP
#
# Below shows an example script for running LatticeFinder on an HCP crystal structure

# %%
from LatticeFinder import LatticeFinder_Program
import numpy as np

symbol = 'Au'
lattice_type = 'FaceCenteredCubic'

lattice_constant_parameters = list(np.arange(2.0,3.5,0.1))+list(np.arange(3.5,5.0,0.001))+list(np.arange(5.0,6.0,0.1))

calculator = 'VASP'
slurm_information = {}
slurm_information['project'] = 'uoo02568'
slurm_information['time'] = '2:00:00'
slurm_information['nodes'] = 1
slurm_information['ntasks_per_node'] = 8
slurm_information['mem-per-cpu'] = '3G'
slurm_information['partition'] = 'large'
slurm_information['email'] = 'geoffreywealslurmnotifications@gmail.com'
slurm_information['python_version'] = 'Python/3.6.3-gimkl-2017a'
slurm_information['vasp_version'] = 'VASP/5.4.4-intel-2017a'
slurm_information['vasp_execution'] = 'vasp_std'

slurm_information['Make individual or packet submitSL files'] = 'packets'
slurm_information['Number of VASP calculations to run per packet'] = 25

size=(1,1,1)

directions=[]
miller=[]

limits = None
make_svg_eps_files = False

no_of_cpus=1

# %% [markdown]
# [Back To Table of Contents](../../LatticeFinder_Jupyter_Example.ipynb)

# %% [markdown]
# ## Run LatticeFinder!
#
# You have got to the end of all the parameter setting stuff. Now on to running LatticeFinder. The next part of the ``Run_LatticeFinder.py`` script tells LatticeFinder to run. This is written as follows in the ``Run_LatticeFinder.py``. This may take a bit of time to run.

# %%
LatticeFinder_Program(symbol, lattice_type, lattice_constant_parameters, calculator, size=size, directions=directions, miller=miller, no_of_cpus=no_of_cpus, limits=limits, make_svg_eps_files=make_svg_eps_files, slurm_information=slurm_information)
# Out:
# =========================================================
#
#             This is the LATTICEFINDER Program
#             Version: 1.1.2.5
#
# =========================================================
# Input settings:
#
# symbol: Au
# lattice_type: FaceCenteredCubic
# lattice_constant_parameters: [2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.7, 2.8, 2.9, 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.501, 3.502, 3.503, 3.504, 3.505, 3.506, 3.507, 3.508, 3.509, 3.51, 3.511, 3.512, 3.513, 3.514, 3.515, 3.516, 3.517, 3.518, 3.519, 3.52, 3.521, 3.522, 3.523, 3.524, 3.525, 3.526, 3.527, 3.528, 3.529, 3.53, 3.531, 3.532, 3.533, 3.534, 3.535, 3.536, 3.537, 3.538, 3.539, 3.54, 3.541, 3.542, 3.543, 3.544, 3.545, 3.546, 3.547, 3.548, 3.549, 3.55, 3.551, 3.552, 3.553, 3.554, 3.555, 3.556, 3.557, 3.558, 3.559, 3.56, 3.561, 3.562, 3.563, 3.564, 3.565, 3.566, 3.567, 3.568, 3.569, 3.57, 3.571, 3.572, 3.573, 3.574, 3.575, 3.576, 3.577, 3.578, 3.579, 3.58, 3.581, 3.582, 3.583, 3.584, 3.585, 3.586, 3.587, 3.588, 3.589, 3.59, 3.591, 3.592, 3.593, 3.594, 3.595, 3.596, 3.597, 3.598, 3.599, 3.6, 3.601, 3.602, 3.603, 3.604, 3.605, 3.606, 3.607, 3.608, 3.609, 3.61, 3.611, 3.612, 3.613, 3.614, 3.615, 3.616, 3.617, 3.618, 3.619, 3.62, 3.621, 3.622, 3.623, 3.624, 3.625, 3.626, 3.627, 3.628, 3.629, 3.63, 3.631, 3.632, 3.633, 3.634, 3.635, 3.636, 3.637, 3.638, 3.639, 3.64, 3.641, 3.642, 3.643, 3.644, 3.645, 3.646, 3.647, 3.648, 3.649, 3.65, 3.651, 3.652, 3.653, 3.654, 3.655, 3.656, 3.657, 3.658, 3.659, 3.66, 3.661, 3.662, 3.663, 3.664, 3.665, 3.666, 3.667, 3.668, 3.669, 3.67, 3.671, 3.672, 3.673, 3.674, 3.675, 3.676, 3.677, 3.678, 3.679, 3.68, 3.681, 3.682, 3.683, 3.684, 3.685, 3.686, 3.687, 3.688, 3.689, 3.69, 3.691, 3.692, 3.693, 3.694, 3.695, 3.696, 3.697, 3.698, 3.699, 3.7, 3.701, 3.702, 3.703, 3.704, 3.705, 3.706, 3.707, 3.708, 3.709, 3.71, 3.711, 3.712, 3.713, 3.714, 3.715, 3.716, 3.717, 3.718, 3.719, 3.72, 3.721, 3.722, 3.723, 3.724, 3.725, 3.726, 3.727, 3.728, 3.729, 3.73, 3.731, 3.732, 3.733, 3.734, 3.735, 3.736, 3.737, 3.738, 3.739, 3.74, 3.741, 3.742, 3.743, 3.744, 3.745, 3.746, 3.747, 3.748, 3.749, 3.75, 3.751, 3.752, 3.753, 3.754, 3.755, 3.756, 3.757, 3.758, 3.759, 3.76, 3.761, 3.762, 3.763, 3.764, 3.765, 3.766, 3.767, 3.768, 3.769, 3.77, 3.771, 3.772, 3.773, 3.774, 3.775, 3.776, 3.777, 3.778, 3.779, 3.78, 3.781, 3.782, 3.783, 3.784, 3.785, 3.786, 3.787, 3.788, 3.789, 3.79, 3.791, 3.792, 3.793, 3.794, 3.795, 3.796, 3.797, 3.798, 3.799, 3.8, 3.801, 3.802, 3.803, 3.804, 3.805, 3.806, 3.807, 3.808, 3.809, 3.81, 3.811, 3.812, 3.813, 3.814, 3.815, 3.816, 3.817, 3.818, 3.819, 3.82, 3.821, 3.822, 3.823, 3.824, 3.825, 3.826, 3.827, 3.828, 3.829, 3.83, 3.831, 3.832, 3.833, 3.834, 3.835, 3.836, 3.837, 3.838, 3.839, 3.84, 3.841, 3.842, 3.843, 3.844, 3.845, 3.846, 3.847, 3.848, 3.849, 3.85, 3.851, 3.852, 3.853, 3.854, 3.855, 3.856, 3.857, 3.858, 3.859, 3.86, 3.861, 3.862, 3.863, 3.864, 3.865, 3.866, 3.867, 3.868, 3.869, 3.87, 3.871, 3.872, 3.873, 3.874, 3.875, 3.876, 3.877, 3.878, 3.879, 3.88, 3.881, 3.882, 3.883, 3.884, 3.885, 3.886, 3.887, 3.888, 3.889, 3.89, 3.891, 3.892, 3.893, 3.894, 3.895, 3.896, 3.897, 3.898, 3.899, 3.9, 3.901, 3.902, 3.903, 3.904, 3.905, 3.906, 3.907, 3.908, 3.909, 3.91, 3.911, 3.912, 3.913, 3.914, 3.915, 3.916, 3.917, 3.918, 3.919, 3.92, 3.921, 3.922, 3.923, 3.924, 3.925, 3.926, 3.927, 3.928, 3.929, 3.93, 3.931, 3.932, 3.933, 3.934, 3.935, 3.936, 3.937, 3.938, 3.939, 3.94, 3.941, 3.942, 3.943, 3.944, 3.945, 3.946, 3.947, 3.948, 3.949, 3.95, 3.951, 3.952, 3.953, 3.954, 3.955, 3.956, 3.957, 3.958, 3.959, 3.96, 3.961, 3.962, 3.963, 3.964, 3.965, 3.966, 3.967, 3.968, 3.969, 3.97, 3.971, 3.972, 3.973, 3.974, 3.975, 3.976, 3.977, 3.978, 3.979, 3.98, 3.981, 3.982, 3.983, 3.984, 3.985, 3.986, 3.987, 3.988, 3.989, 3.99, 3.991, 3.992, 3.993, 3.994, 3.995, 3.996, 3.997, 3.998, 3.999, 4.0, 4.001, 4.002, 4.003, 4.004, 4.005, 4.006, 4.007, 4.008, 4.009, 4.01, 4.011, 4.012, 4.013, 4.014, 4.015, 4.016, 4.017, 4.018, 4.019, 4.02, 4.021, 4.022, 4.023, 4.024, 4.025, 4.026, 4.027, 4.028, 4.029, 4.03, 4.031, 4.032, 4.033, 4.034, 4.035, 4.036, 4.037, 4.038, 4.039, 4.04, 4.041, 4.042, 4.043, 4.044, 4.045, 4.046, 4.047, 4.048, 4.049, 4.05, 4.051, 4.052, 4.053, 4.054, 4.055, 4.056, 4.057, 4.058, 4.059, 4.06, 4.061, 4.062, 4.063, 4.064, 4.0 ...
# calculator: VASP
# size: (1, 1, 1)
# directions: []
# miller: []
# =========================================================
# Output settings:
#
# limits
# slurm_information: {'project': 'uoo02568', 'time': '2:00:00', 'nodes': 1, 'ntasks_per_node': 8, 'mem-per-cpu': '3G', 'partition': 'large', 'email': 'geoffreywealslurmnotifications@gmail.com', 'python_version': 'Python/3.6.3-gimkl-2017a', 'vasp_version': 'VASP/5.4.4-intel-2017a', 'vasp_execution': 'vasp_std', 'Make individual or packet submitSL files': 'packets', 'Number of VASP calculations to run per packet': 25}
# =========================================================
# Other settings:
#
# no_of_cpus: 1
# =========================================================
# ===============================================================
# Loading data
# Finished Loading data
# ===============================================================
# ===============================================================
# Getting data
# Not getting data, instead making clusters for running in VASP.
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.0
# creating submit.sl for VASP_Systems/c_2.0
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.1
# creating submit.sl for VASP_Systems/c_2.1
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.2
# creating submit.sl for VASP_Systems/c_2.2
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.3
# creating submit.sl for VASP_Systems/c_2.3
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.4
# creating submit.sl for VASP_Systems/c_2.4
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.5
# creating submit.sl for VASP_Systems/c_2.5
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.6
# creating submit.sl for VASP_Systems/c_2.6
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.7
# creating submit.sl for VASP_Systems/c_2.7
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.8
# creating submit.sl for VASP_Systems/c_2.8
# NSW = 0
# Copying VASP files to VASP_Systems/c_2.9
# creating submit.sl for VASP_Systems/c_2.9
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.0
# creating submit.sl for VASP_Systems/c_3.0
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.1
# creating submit.sl for VASP_Systems/c_3.1
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.2
# creating submit.sl for VASP_Systems/c_3.2
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.3
# creating submit.sl for VASP_Systems/c_3.3
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.4
# creating submit.sl for VASP_Systems/c_3.4
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.5
# creating submit.sl for VASP_Systems/c_3.5
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.501
# creating submit.sl for VASP_Systems/c_3.501
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.502
# creating submit.sl for VASP_Systems/c_3.502
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.503
# creating submit.sl for VASP_Systems/c_3.503
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.504
# creating submit.sl for VASP_Systems/c_3.504
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.505
# creating submit.sl for VASP_Systems/c_3.505
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.506
# creating submit.sl for VASP_Systems/c_3.506
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.507
# creating submit.sl for VASP_Systems/c_3.507
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.508
# creating submit.sl for VASP_Systems/c_3.508
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.509
# creating submit.sl for VASP_Systems/c_3.509
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.51
# creating submit.sl for VASP_Systems/c_3.51
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.511
# creating submit.sl for VASP_Systems/c_3.511
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.512
# creating submit.sl for VASP_Systems/c_3.512
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.513
# creating submit.sl for VASP_Systems/c_3.513
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.514
# creating submit.sl for VASP_Systems/c_3.514
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.515
# creating submit.sl for VASP_Systems/c_3.515
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.516
# creating submit.sl for VASP_Systems/c_3.516
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.517
# creating submit.sl for VASP_Systems/c_3.517
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.518
# creating submit.sl for VASP_Systems/c_3.518
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.519
# creating submit.sl for VASP_Systems/c_3.519
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.52
# creating submit.sl for VASP_Systems/c_3.52
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.521
# creating submit.sl for VASP_Systems/c_3.521
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.522
# creating submit.sl for VASP_Systems/c_3.522
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.523
# creating submit.sl for VASP_Systems/c_3.523
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.524
# creating submit.sl for VASP_Systems/c_3.524
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.525
# creating submit.sl for VASP_Systems/c_3.525
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.526
# creating submit.sl for VASP_Systems/c_3.526
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.527
# creating submit.sl for VASP_Systems/c_3.527
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.528
# creating submit.sl for VASP_Systems/c_3.528
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.529
# creating submit.sl for VASP_Systems/c_3.529
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.53
# creating submit.sl for VASP_Systems/c_3.53
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.531
# creating submit.sl for VASP_Systems/c_3.531
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.532
# creating submit.sl for VASP_Systems/c_3.532
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.533
# creating submit.sl for VASP_Systems/c_3.533
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.534
# creating submit.sl for VASP_Systems/c_3.534
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.535
# creating submit.sl for VASP_Systems/c_3.535
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.536
# creating submit.sl for VASP_Systems/c_3.536
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.537
# creating submit.sl for VASP_Systems/c_3.537
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.538
# creating submit.sl for VASP_Systems/c_3.538
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.539
# creating submit.sl for VASP_Systems/c_3.539
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.54
# creating submit.sl for VASP_Systems/c_3.54
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.541
# creating submit.sl for VASP_Systems/c_3.541
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.542
# creating submit.sl for VASP_Systems/c_3.542
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.543
# creating submit.sl for VASP_Systems/c_3.543
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.544
# creating submit.sl for VASP_Systems/c_3.544
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.545
# creating submit.sl for VASP_Systems/c_3.545
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.546
# creating submit.sl for VASP_Systems/c_3.546
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.547
# creating submit.sl for VASP_Systems/c_3.547
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.548
# creating submit.sl for VASP_Systems/c_3.548
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.549
# creating submit.sl for VASP_Systems/c_3.549
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.55
# creating submit.sl for VASP_Systems/c_3.55
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.551
# creating submit.sl for VASP_Systems/c_3.551
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.552
# creating submit.sl for VASP_Systems/c_3.552
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.553
# creating submit.sl for VASP_Systems/c_3.553
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.554
# creating submit.sl for VASP_Systems/c_3.554
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.555
# creating submit.sl for VASP_Systems/c_3.555
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.556
# creating submit.sl for VASP_Systems/c_3.556
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.557
# creating submit.sl for VASP_Systems/c_3.557
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.558
# creating submit.sl for VASP_Systems/c_3.558
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.559
# creating submit.sl for VASP_Systems/c_3.559
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.56
# creating submit.sl for VASP_Systems/c_3.56
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.561
# creating submit.sl for VASP_Systems/c_3.561
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.562
# creating submit.sl for VASP_Systems/c_3.562
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.563
# creating submit.sl for VASP_Systems/c_3.563
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.564
# creating submit.sl for VASP_Systems/c_3.564
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.565
# creating submit.sl for VASP_Systems/c_3.565
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.566
# creating submit.sl for VASP_Systems/c_3.566
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.567
# creating submit.sl for VASP_Systems/c_3.567
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.568
# creating submit.sl for VASP_Systems/c_3.568
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.569
# creating submit.sl for VASP_Systems/c_3.569
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.57
# creating submit.sl for VASP_Systems/c_3.57
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.571
# creating submit.sl for VASP_Systems/c_3.571
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.572
# creating submit.sl for VASP_Systems/c_3.572
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.573
# creating submit.sl for VASP_Systems/c_3.573
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.574
# creating submit.sl for VASP_Systems/c_3.574
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.575
# creating submit.sl for VASP_Systems/c_3.575
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.576
# creating submit.sl for VASP_Systems/c_3.576
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.577
# creating submit.sl for VASP_Systems/c_3.577
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.578
# creating submit.sl for VASP_Systems/c_3.578
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.579
# creating submit.sl for VASP_Systems/c_3.579
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.58
# creating submit.sl for VASP_Systems/c_3.58
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.581
# creating submit.sl for VASP_Systems/c_3.581
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.582
# creating submit.sl for VASP_Systems/c_3.582
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.583
# creating submit.sl for VASP_Systems/c_3.583
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.584
# creating submit.sl for VASP_Systems/c_3.584
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.585
# creating submit.sl for VASP_Systems/c_3.585
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.586
# creating submit.sl for VASP_Systems/c_3.586
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.587
# creating submit.sl for VASP_Systems/c_3.587
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.588
# creating submit.sl for VASP_Systems/c_3.588
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.589
# creating submit.sl for VASP_Systems/c_3.589
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.59
# creating submit.sl for VASP_Systems/c_3.59
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.591
# creating submit.sl for VASP_Systems/c_3.591
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.592
# creating submit.sl for VASP_Systems/c_3.592
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.593
# creating submit.sl for VASP_Systems/c_3.593
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.594
# creating submit.sl for VASP_Systems/c_3.594
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.595
# creating submit.sl for VASP_Systems/c_3.595
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.596
# creating submit.sl for VASP_Systems/c_3.596
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.597
# creating submit.sl for VASP_Systems/c_3.597
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.598
# creating submit.sl for VASP_Systems/c_3.598
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.599
# creating submit.sl for VASP_Systems/c_3.599
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.6
# creating submit.sl for VASP_Systems/c_3.6
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.601
# creating submit.sl for VASP_Systems/c_3.601
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.602
# creating submit.sl for VASP_Systems/c_3.602
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.603
# creating submit.sl for VASP_Systems/c_3.603
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.604
# creating submit.sl for VASP_Systems/c_3.604
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.605
# creating submit.sl for VASP_Systems/c_3.605
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.606
# creating submit.sl for VASP_Systems/c_3.606
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.607
# creating submit.sl for VASP_Systems/c_3.607
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.608
# creating submit.sl for VASP_Systems/c_3.608
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.609
# creating submit.sl for VASP_Systems/c_3.609
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.61
# creating submit.sl for VASP_Systems/c_3.61
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.611
# creating submit.sl for VASP_Systems/c_3.611
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.612
# creating submit.sl for VASP_Systems/c_3.612
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.613
# creating submit.sl for VASP_Systems/c_3.613
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.614
# creating submit.sl for VASP_Systems/c_3.614
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.615
# creating submit.sl for VASP_Systems/c_3.615
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.616
# creating submit.sl for VASP_Systems/c_3.616
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.617
# creating submit.sl for VASP_Systems/c_3.617
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.618
# creating submit.sl for VASP_Systems/c_3.618
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.619
# creating submit.sl for VASP_Systems/c_3.619
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.62
# creating submit.sl for VASP_Systems/c_3.62
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.621
# creating submit.sl for VASP_Systems/c_3.621
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.622
# creating submit.sl for VASP_Systems/c_3.622
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.623
# creating submit.sl for VASP_Systems/c_3.623
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.624
# creating submit.sl for VASP_Systems/c_3.624
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.625
# creating submit.sl for VASP_Systems/c_3.625
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.626
# creating submit.sl for VASP_Systems/c_3.626
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.627
# creating submit.sl for VASP_Systems/c_3.627
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.628
# creating submit.sl for VASP_Systems/c_3.628
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.629
# creating submit.sl for VASP_Systems/c_3.629
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.63
# creating submit.sl for VASP_Systems/c_3.63
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.631
# creating submit.sl for VASP_Systems/c_3.631
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.632
# creating submit.sl for VASP_Systems/c_3.632
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.633
# creating submit.sl for VASP_Systems/c_3.633
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.634
# creating submit.sl for VASP_Systems/c_3.634
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.635
# creating submit.sl for VASP_Systems/c_3.635
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.636
# creating submit.sl for VASP_Systems/c_3.636
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.637
# creating submit.sl for VASP_Systems/c_3.637
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.638
# creating submit.sl for VASP_Systems/c_3.638
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.639
# creating submit.sl for VASP_Systems/c_3.639
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.64
# creating submit.sl for VASP_Systems/c_3.64
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.641
# creating submit.sl for VASP_Systems/c_3.641
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.642
# creating submit.sl for VASP_Systems/c_3.642
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.643
# creating submit.sl for VASP_Systems/c_3.643
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.644
# creating submit.sl for VASP_Systems/c_3.644
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.645
# creating submit.sl for VASP_Systems/c_3.645
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.646
# creating submit.sl for VASP_Systems/c_3.646
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.647
# creating submit.sl for VASP_Systems/c_3.647
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.648
# creating submit.sl for VASP_Systems/c_3.648
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.649
# creating submit.sl for VASP_Systems/c_3.649
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.65
# creating submit.sl for VASP_Systems/c_3.65
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.651
# creating submit.sl for VASP_Systems/c_3.651
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.652
# creating submit.sl for VASP_Systems/c_3.652
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.653
# creating submit.sl for VASP_Systems/c_3.653
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.654
# creating submit.sl for VASP_Systems/c_3.654
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.655
# creating submit.sl for VASP_Systems/c_3.655
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.656
# creating submit.sl for VASP_Systems/c_3.656
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.657
# creating submit.sl for VASP_Systems/c_3.657
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.658
# creating submit.sl for VASP_Systems/c_3.658
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.659
# creating submit.sl for VASP_Systems/c_3.659
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.66
# creating submit.sl for VASP_Systems/c_3.66
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.661
# creating submit.sl for VASP_Systems/c_3.661
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.662
# creating submit.sl for VASP_Systems/c_3.662
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.663
# creating submit.sl for VASP_Systems/c_3.663
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.664
# creating submit.sl for VASP_Systems/c_3.664
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.665
# creating submit.sl for VASP_Systems/c_3.665
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.666
# creating submit.sl for VASP_Systems/c_3.666
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.667
# creating submit.sl for VASP_Systems/c_3.667
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.668
# creating submit.sl for VASP_Systems/c_3.668
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.669
# creating submit.sl for VASP_Systems/c_3.669
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.67
# creating submit.sl for VASP_Systems/c_3.67
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.671
# creating submit.sl for VASP_Systems/c_3.671
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.672
# creating submit.sl for VASP_Systems/c_3.672
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.673
# creating submit.sl for VASP_Systems/c_3.673
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.674
# creating submit.sl for VASP_Systems/c_3.674
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.675
# creating submit.sl for VASP_Systems/c_3.675
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.676
# creating submit.sl for VASP_Systems/c_3.676
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.677
# creating submit.sl for VASP_Systems/c_3.677
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.678
# creating submit.sl for VASP_Systems/c_3.678
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.679
# creating submit.sl for VASP_Systems/c_3.679
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.68
# creating submit.sl for VASP_Systems/c_3.68
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.681
# creating submit.sl for VASP_Systems/c_3.681
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.682
# creating submit.sl for VASP_Systems/c_3.682
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.683
# creating submit.sl for VASP_Systems/c_3.683
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.684
# creating submit.sl for VASP_Systems/c_3.684
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.685
# creating submit.sl for VASP_Systems/c_3.685
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.686
# creating submit.sl for VASP_Systems/c_3.686
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.687
# creating submit.sl for VASP_Systems/c_3.687
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.688
# creating submit.sl for VASP_Systems/c_3.688
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.689
# creating submit.sl for VASP_Systems/c_3.689
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.69
# creating submit.sl for VASP_Systems/c_3.69
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.691
# creating submit.sl for VASP_Systems/c_3.691
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.692
# creating submit.sl for VASP_Systems/c_3.692
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.693
# creating submit.sl for VASP_Systems/c_3.693
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.694
# creating submit.sl for VASP_Systems/c_3.694
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.695
# creating submit.sl for VASP_Systems/c_3.695
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.696
# creating submit.sl for VASP_Systems/c_3.696
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.697
# creating submit.sl for VASP_Systems/c_3.697
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.698
# creating submit.sl for VASP_Systems/c_3.698
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.699
# creating submit.sl for VASP_Systems/c_3.699
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.7
# creating submit.sl for VASP_Systems/c_3.7
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.701
# creating submit.sl for VASP_Systems/c_3.701
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.702
# creating submit.sl for VASP_Systems/c_3.702
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.703
# creating submit.sl for VASP_Systems/c_3.703
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.704
# creating submit.sl for VASP_Systems/c_3.704
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.705
# creating submit.sl for VASP_Systems/c_3.705
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.706
# creating submit.sl for VASP_Systems/c_3.706
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.707
# creating submit.sl for VASP_Systems/c_3.707
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.708
# creating submit.sl for VASP_Systems/c_3.708
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.709
# creating submit.sl for VASP_Systems/c_3.709
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.71
# creating submit.sl for VASP_Systems/c_3.71
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.711
# creating submit.sl for VASP_Systems/c_3.711
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.712
# creating submit.sl for VASP_Systems/c_3.712
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.713
# creating submit.sl for VASP_Systems/c_3.713
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.714
# creating submit.sl for VASP_Systems/c_3.714
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.715
# creating submit.sl for VASP_Systems/c_3.715
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.716
# creating submit.sl for VASP_Systems/c_3.716
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.717
# creating submit.sl for VASP_Systems/c_3.717
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.718
# creating submit.sl for VASP_Systems/c_3.718
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.719
# creating submit.sl for VASP_Systems/c_3.719
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.72
# creating submit.sl for VASP_Systems/c_3.72
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.721
# creating submit.sl for VASP_Systems/c_3.721
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.722
# creating submit.sl for VASP_Systems/c_3.722
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.723
# creating submit.sl for VASP_Systems/c_3.723
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.724
# creating submit.sl for VASP_Systems/c_3.724
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.725
# creating submit.sl for VASP_Systems/c_3.725
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.726
# creating submit.sl for VASP_Systems/c_3.726
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.727
# creating submit.sl for VASP_Systems/c_3.727
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.728
# creating submit.sl for VASP_Systems/c_3.728
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.729
# creating submit.sl for VASP_Systems/c_3.729
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.73
# creating submit.sl for VASP_Systems/c_3.73
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.731
# creating submit.sl for VASP_Systems/c_3.731
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.732
# creating submit.sl for VASP_Systems/c_3.732
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.733
# creating submit.sl for VASP_Systems/c_3.733
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.734
# creating submit.sl for VASP_Systems/c_3.734
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.735
# creating submit.sl for VASP_Systems/c_3.735
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.736
# creating submit.sl for VASP_Systems/c_3.736
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.737
# creating submit.sl for VASP_Systems/c_3.737
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.738
# creating submit.sl for VASP_Systems/c_3.738
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.739
# creating submit.sl for VASP_Systems/c_3.739
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.74
# creating submit.sl for VASP_Systems/c_3.74
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.741
# creating submit.sl for VASP_Systems/c_3.741
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.742
# creating submit.sl for VASP_Systems/c_3.742
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.743
# creating submit.sl for VASP_Systems/c_3.743
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.744
# creating submit.sl for VASP_Systems/c_3.744
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.745
# creating submit.sl for VASP_Systems/c_3.745
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.746
# creating submit.sl for VASP_Systems/c_3.746
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.747
# creating submit.sl for VASP_Systems/c_3.747
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.748
# creating submit.sl for VASP_Systems/c_3.748
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.749
# creating submit.sl for VASP_Systems/c_3.749
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.75
# creating submit.sl for VASP_Systems/c_3.75
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.751
# creating submit.sl for VASP_Systems/c_3.751
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.752
# creating submit.sl for VASP_Systems/c_3.752
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.753
# creating submit.sl for VASP_Systems/c_3.753
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.754
# creating submit.sl for VASP_Systems/c_3.754
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.755
# creating submit.sl for VASP_Systems/c_3.755
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.756
# creating submit.sl for VASP_Systems/c_3.756
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.757
# creating submit.sl for VASP_Systems/c_3.757
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.758
# creating submit.sl for VASP_Systems/c_3.758
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.759
# creating submit.sl for VASP_Systems/c_3.759
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.76
# creating submit.sl for VASP_Systems/c_3.76
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.761
# creating submit.sl for VASP_Systems/c_3.761
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.762
# creating submit.sl for VASP_Systems/c_3.762
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.763
# creating submit.sl for VASP_Systems/c_3.763
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.764
# creating submit.sl for VASP_Systems/c_3.764
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.765
# creating submit.sl for VASP_Systems/c_3.765
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.766
# creating submit.sl for VASP_Systems/c_3.766
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.767
# creating submit.sl for VASP_Systems/c_3.767
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.768
# creating submit.sl for VASP_Systems/c_3.768
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.769
# creating submit.sl for VASP_Systems/c_3.769
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.77
# creating submit.sl for VASP_Systems/c_3.77
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.771
# creating submit.sl for VASP_Systems/c_3.771
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.772
# creating submit.sl for VASP_Systems/c_3.772
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.773
# creating submit.sl for VASP_Systems/c_3.773
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.774
# creating submit.sl for VASP_Systems/c_3.774
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.775
# creating submit.sl for VASP_Systems/c_3.775
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.776
# creating submit.sl for VASP_Systems/c_3.776
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.777
# creating submit.sl for VASP_Systems/c_3.777
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.778
# creating submit.sl for VASP_Systems/c_3.778
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.779
# creating submit.sl for VASP_Systems/c_3.779
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.78
# creating submit.sl for VASP_Systems/c_3.78
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.781
# creating submit.sl for VASP_Systems/c_3.781
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.782
# creating submit.sl for VASP_Systems/c_3.782
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.783
# creating submit.sl for VASP_Systems/c_3.783
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.784
# creating submit.sl for VASP_Systems/c_3.784
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.785
# creating submit.sl for VASP_Systems/c_3.785
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.786
# creating submit.sl for VASP_Systems/c_3.786
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.787
# creating submit.sl for VASP_Systems/c_3.787
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.788
# creating submit.sl for VASP_Systems/c_3.788
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.789
# creating submit.sl for VASP_Systems/c_3.789
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.79
# creating submit.sl for VASP_Systems/c_3.79
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.791
# creating submit.sl for VASP_Systems/c_3.791
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.792
# creating submit.sl for VASP_Systems/c_3.792
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.793
# creating submit.sl for VASP_Systems/c_3.793
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.794
# creating submit.sl for VASP_Systems/c_3.794
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.795
# creating submit.sl for VASP_Systems/c_3.795
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.796
# creating submit.sl for VASP_Systems/c_3.796
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.797
# creating submit.sl for VASP_Systems/c_3.797
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.798
# creating submit.sl for VASP_Systems/c_3.798
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.799
# creating submit.sl for VASP_Systems/c_3.799
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.8
# creating submit.sl for VASP_Systems/c_3.8
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.801
# creating submit.sl for VASP_Systems/c_3.801
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.802
# creating submit.sl for VASP_Systems/c_3.802
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.803
# creating submit.sl for VASP_Systems/c_3.803
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.804
# creating submit.sl for VASP_Systems/c_3.804
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.805
# creating submit.sl for VASP_Systems/c_3.805
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.806
# creating submit.sl for VASP_Systems/c_3.806
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.807
# creating submit.sl for VASP_Systems/c_3.807
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.808
# creating submit.sl for VASP_Systems/c_3.808
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.809
# creating submit.sl for VASP_Systems/c_3.809
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.81
# creating submit.sl for VASP_Systems/c_3.81
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.811
# creating submit.sl for VASP_Systems/c_3.811
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.812
# creating submit.sl for VASP_Systems/c_3.812
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.813
# creating submit.sl for VASP_Systems/c_3.813
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.814
# creating submit.sl for VASP_Systems/c_3.814
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.815
# creating submit.sl for VASP_Systems/c_3.815
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.816
# creating submit.sl for VASP_Systems/c_3.816
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.817
# creating submit.sl for VASP_Systems/c_3.817
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.818
# creating submit.sl for VASP_Systems/c_3.818
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.819
# creating submit.sl for VASP_Systems/c_3.819
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.82
# creating submit.sl for VASP_Systems/c_3.82
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.821
# creating submit.sl for VASP_Systems/c_3.821
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.822
# creating submit.sl for VASP_Systems/c_3.822
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.823
# creating submit.sl for VASP_Systems/c_3.823
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.824
# creating submit.sl for VASP_Systems/c_3.824
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.825
# creating submit.sl for VASP_Systems/c_3.825
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.826
# creating submit.sl for VASP_Systems/c_3.826
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.827
# creating submit.sl for VASP_Systems/c_3.827
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.828
# creating submit.sl for VASP_Systems/c_3.828
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.829
# creating submit.sl for VASP_Systems/c_3.829
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.83
# creating submit.sl for VASP_Systems/c_3.83
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.831
# creating submit.sl for VASP_Systems/c_3.831
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.832
# creating submit.sl for VASP_Systems/c_3.832
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.833
# creating submit.sl for VASP_Systems/c_3.833
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.834
# creating submit.sl for VASP_Systems/c_3.834
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.835
# creating submit.sl for VASP_Systems/c_3.835
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.836
# creating submit.sl for VASP_Systems/c_3.836
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.837
# creating submit.sl for VASP_Systems/c_3.837
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.838
# creating submit.sl for VASP_Systems/c_3.838
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.839
# creating submit.sl for VASP_Systems/c_3.839
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.84
# creating submit.sl for VASP_Systems/c_3.84
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.841
# creating submit.sl for VASP_Systems/c_3.841
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.842
# creating submit.sl for VASP_Systems/c_3.842
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.843
# creating submit.sl for VASP_Systems/c_3.843
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.844
# creating submit.sl for VASP_Systems/c_3.844
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.845
# creating submit.sl for VASP_Systems/c_3.845
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.846
# creating submit.sl for VASP_Systems/c_3.846
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.847
# creating submit.sl for VASP_Systems/c_3.847
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.848
# creating submit.sl for VASP_Systems/c_3.848
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.849
# creating submit.sl for VASP_Systems/c_3.849
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.85
# creating submit.sl for VASP_Systems/c_3.85
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.851
# creating submit.sl for VASP_Systems/c_3.851
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.852
# creating submit.sl for VASP_Systems/c_3.852
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.853
# creating submit.sl for VASP_Systems/c_3.853
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.854
# creating submit.sl for VASP_Systems/c_3.854
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.855
# creating submit.sl for VASP_Systems/c_3.855
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.856
# creating submit.sl for VASP_Systems/c_3.856
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.857
# creating submit.sl for VASP_Systems/c_3.857
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.858
# creating submit.sl for VASP_Systems/c_3.858
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.859
# creating submit.sl for VASP_Systems/c_3.859
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.86
# creating submit.sl for VASP_Systems/c_3.86
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.861
# creating submit.sl for VASP_Systems/c_3.861
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.862
# creating submit.sl for VASP_Systems/c_3.862
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.863
# creating submit.sl for VASP_Systems/c_3.863
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.864
# creating submit.sl for VASP_Systems/c_3.864
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.865
# creating submit.sl for VASP_Systems/c_3.865
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.866
# creating submit.sl for VASP_Systems/c_3.866
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.867
# creating submit.sl for VASP_Systems/c_3.867
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.868
# creating submit.sl for VASP_Systems/c_3.868
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.869
# creating submit.sl for VASP_Systems/c_3.869
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.87
# creating submit.sl for VASP_Systems/c_3.87
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.871
# creating submit.sl for VASP_Systems/c_3.871
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.872
# creating submit.sl for VASP_Systems/c_3.872
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.873
# creating submit.sl for VASP_Systems/c_3.873
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.874
# creating submit.sl for VASP_Systems/c_3.874
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.875
# creating submit.sl for VASP_Systems/c_3.875
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.876
# creating submit.sl for VASP_Systems/c_3.876
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.877
# creating submit.sl for VASP_Systems/c_3.877
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.878
# creating submit.sl for VASP_Systems/c_3.878
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.879
# creating submit.sl for VASP_Systems/c_3.879
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.88
# creating submit.sl for VASP_Systems/c_3.88
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.881
# creating submit.sl for VASP_Systems/c_3.881
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.882
# creating submit.sl for VASP_Systems/c_3.882
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.883
# creating submit.sl for VASP_Systems/c_3.883
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.884
# creating submit.sl for VASP_Systems/c_3.884
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.885
# creating submit.sl for VASP_Systems/c_3.885
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.886
# creating submit.sl for VASP_Systems/c_3.886
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.887
# creating submit.sl for VASP_Systems/c_3.887
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.888
# creating submit.sl for VASP_Systems/c_3.888
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.889
# creating submit.sl for VASP_Systems/c_3.889
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.89
# creating submit.sl for VASP_Systems/c_3.89
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.891
# creating submit.sl for VASP_Systems/c_3.891
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.892
# creating submit.sl for VASP_Systems/c_3.892
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.893
# creating submit.sl for VASP_Systems/c_3.893
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.894
# creating submit.sl for VASP_Systems/c_3.894
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.895
# creating submit.sl for VASP_Systems/c_3.895
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.896
# creating submit.sl for VASP_Systems/c_3.896
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.897
# creating submit.sl for VASP_Systems/c_3.897
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.898
# creating submit.sl for VASP_Systems/c_3.898
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.899
# creating submit.sl for VASP_Systems/c_3.899
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.9
# creating submit.sl for VASP_Systems/c_3.9
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.901
# creating submit.sl for VASP_Systems/c_3.901
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.902
# creating submit.sl for VASP_Systems/c_3.902
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.903
# creating submit.sl for VASP_Systems/c_3.903
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.904
# creating submit.sl for VASP_Systems/c_3.904
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.905
# creating submit.sl for VASP_Systems/c_3.905
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.906
# creating submit.sl for VASP_Systems/c_3.906
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.907
# creating submit.sl for VASP_Systems/c_3.907
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.908
# creating submit.sl for VASP_Systems/c_3.908
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.909
# creating submit.sl for VASP_Systems/c_3.909
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.91
# creating submit.sl for VASP_Systems/c_3.91
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.911
# creating submit.sl for VASP_Systems/c_3.911
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.912
# creating submit.sl for VASP_Systems/c_3.912
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.913
# creating submit.sl for VASP_Systems/c_3.913
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.914
# creating submit.sl for VASP_Systems/c_3.914
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.915
# creating submit.sl for VASP_Systems/c_3.915
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.916
# creating submit.sl for VASP_Systems/c_3.916
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.917
# creating submit.sl for VASP_Systems/c_3.917
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.918
# creating submit.sl for VASP_Systems/c_3.918
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.919
# creating submit.sl for VASP_Systems/c_3.919
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.92
# creating submit.sl for VASP_Systems/c_3.92
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.921
# creating submit.sl for VASP_Systems/c_3.921
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.922
# creating submit.sl for VASP_Systems/c_3.922
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.923
# creating submit.sl for VASP_Systems/c_3.923
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.924
# creating submit.sl for VASP_Systems/c_3.924
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.925
# creating submit.sl for VASP_Systems/c_3.925
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.926
# creating submit.sl for VASP_Systems/c_3.926
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.927
# creating submit.sl for VASP_Systems/c_3.927
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.928
# creating submit.sl for VASP_Systems/c_3.928
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.929
# creating submit.sl for VASP_Systems/c_3.929
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.93
# creating submit.sl for VASP_Systems/c_3.93
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.931
# creating submit.sl for VASP_Systems/c_3.931
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.932
# creating submit.sl for VASP_Systems/c_3.932
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.933
# creating submit.sl for VASP_Systems/c_3.933
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.934
# creating submit.sl for VASP_Systems/c_3.934
# NSW = 0
# Copying VASP files to VASP_Systems/c_3.935
# creating submit.sl for VASP_Systems/c_3.935
# NSW = 0
# ...
# Copying VASP files to VASP_Systems/c_4.895
# creating submit.sl for VASP_Systems/c_4.895
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.896
# creating submit.sl for VASP_Systems/c_4.896
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.897
# creating submit.sl for VASP_Systems/c_4.897
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.898
# creating submit.sl for VASP_Systems/c_4.898
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.899
# creating submit.sl for VASP_Systems/c_4.899
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.9
# creating submit.sl for VASP_Systems/c_4.9
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.901
# creating submit.sl for VASP_Systems/c_4.901
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.902
# creating submit.sl for VASP_Systems/c_4.902
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.903
# creating submit.sl for VASP_Systems/c_4.903
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.904
# creating submit.sl for VASP_Systems/c_4.904
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.905
# creating submit.sl for VASP_Systems/c_4.905
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.906
# creating submit.sl for VASP_Systems/c_4.906
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.907
# creating submit.sl for VASP_Systems/c_4.907
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.908
# creating submit.sl for VASP_Systems/c_4.908
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.909
# creating submit.sl for VASP_Systems/c_4.909
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.91
# creating submit.sl for VASP_Systems/c_4.91
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.911
# creating submit.sl for VASP_Systems/c_4.911
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.912
# creating submit.sl for VASP_Systems/c_4.912
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.913
# creating submit.sl for VASP_Systems/c_4.913
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.914
# creating submit.sl for VASP_Systems/c_4.914
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.915
# creating submit.sl for VASP_Systems/c_4.915
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.916
# creating submit.sl for VASP_Systems/c_4.916
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.917
# creating submit.sl for VASP_Systems/c_4.917
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.918
# creating submit.sl for VASP_Systems/c_4.918
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.919
# creating submit.sl for VASP_Systems/c_4.919
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.92
# creating submit.sl for VASP_Systems/c_4.92
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.921
# creating submit.sl for VASP_Systems/c_4.921
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.922
# creating submit.sl for VASP_Systems/c_4.922
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.923
# creating submit.sl for VASP_Systems/c_4.923
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.924
# creating submit.sl for VASP_Systems/c_4.924
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.925
# creating submit.sl for VASP_Systems/c_4.925
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.926
# creating submit.sl for VASP_Systems/c_4.926
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.927
# creating submit.sl for VASP_Systems/c_4.927
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.928
# creating submit.sl for VASP_Systems/c_4.928
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.929
# creating submit.sl for VASP_Systems/c_4.929
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.93
# creating submit.sl for VASP_Systems/c_4.93
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.931
# creating submit.sl for VASP_Systems/c_4.931
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.932
# creating submit.sl for VASP_Systems/c_4.932
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.933
# creating submit.sl for VASP_Systems/c_4.933
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.934
# creating submit.sl for VASP_Systems/c_4.934
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.935
# creating submit.sl for VASP_Systems/c_4.935
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.936
# creating submit.sl for VASP_Systems/c_4.936
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.937
# creating submit.sl for VASP_Systems/c_4.937
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.938
# creating submit.sl for VASP_Systems/c_4.938
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.939
# creating submit.sl for VASP_Systems/c_4.939
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.94
# creating submit.sl for VASP_Systems/c_4.94
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.941
# creating submit.sl for VASP_Systems/c_4.941
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.942
# creating submit.sl for VASP_Systems/c_4.942
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.943
# creating submit.sl for VASP_Systems/c_4.943
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.944
# creating submit.sl for VASP_Systems/c_4.944
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.945
# creating submit.sl for VASP_Systems/c_4.945
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.946
# creating submit.sl for VASP_Systems/c_4.946
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.947
# creating submit.sl for VASP_Systems/c_4.947
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.948
# creating submit.sl for VASP_Systems/c_4.948
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.949
# creating submit.sl for VASP_Systems/c_4.949
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.95
# creating submit.sl for VASP_Systems/c_4.95
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.951
# creating submit.sl for VASP_Systems/c_4.951
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.952
# creating submit.sl for VASP_Systems/c_4.952
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.953
# creating submit.sl for VASP_Systems/c_4.953
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.954
# creating submit.sl for VASP_Systems/c_4.954
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.955
# creating submit.sl for VASP_Systems/c_4.955
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.956
# creating submit.sl for VASP_Systems/c_4.956
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.957
# creating submit.sl for VASP_Systems/c_4.957
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.958
# creating submit.sl for VASP_Systems/c_4.958
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.959
# creating submit.sl for VASP_Systems/c_4.959
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.96
# creating submit.sl for VASP_Systems/c_4.96
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.961
# creating submit.sl for VASP_Systems/c_4.961
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.962
# creating submit.sl for VASP_Systems/c_4.962
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.963
# creating submit.sl for VASP_Systems/c_4.963
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.964
# creating submit.sl for VASP_Systems/c_4.964
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.965
# creating submit.sl for VASP_Systems/c_4.965
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.966
# creating submit.sl for VASP_Systems/c_4.966
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.967
# creating submit.sl for VASP_Systems/c_4.967
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.968
# creating submit.sl for VASP_Systems/c_4.968
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.969
# creating submit.sl for VASP_Systems/c_4.969
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.97
# creating submit.sl for VASP_Systems/c_4.97
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.971
# creating submit.sl for VASP_Systems/c_4.971
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.972
# creating submit.sl for VASP_Systems/c_4.972
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.973
# creating submit.sl for VASP_Systems/c_4.973
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.974
# creating submit.sl for VASP_Systems/c_4.974
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.975
# creating submit.sl for VASP_Systems/c_4.975
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.976
# creating submit.sl for VASP_Systems/c_4.976
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.977
# creating submit.sl for VASP_Systems/c_4.977
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.978
# creating submit.sl for VASP_Systems/c_4.978
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.979
# creating submit.sl for VASP_Systems/c_4.979
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.98
# creating submit.sl for VASP_Systems/c_4.98
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.981
# creating submit.sl for VASP_Systems/c_4.981
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.982
# creating submit.sl for VASP_Systems/c_4.982
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.983
# creating submit.sl for VASP_Systems/c_4.983
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.984
# creating submit.sl for VASP_Systems/c_4.984
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.985
# creating submit.sl for VASP_Systems/c_4.985
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.986
# creating submit.sl for VASP_Systems/c_4.986
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.987
# creating submit.sl for VASP_Systems/c_4.987
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.988
# creating submit.sl for VASP_Systems/c_4.988
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.989
# creating submit.sl for VASP_Systems/c_4.989
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.99
# creating submit.sl for VASP_Systems/c_4.99
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.991
# creating submit.sl for VASP_Systems/c_4.991
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.992
# creating submit.sl for VASP_Systems/c_4.992
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.993
# creating submit.sl for VASP_Systems/c_4.993
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.994
# creating submit.sl for VASP_Systems/c_4.994
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.995
# creating submit.sl for VASP_Systems/c_4.995
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.996
# creating submit.sl for VASP_Systems/c_4.996
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.997
# creating submit.sl for VASP_Systems/c_4.997
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.998
# creating submit.sl for VASP_Systems/c_4.998
# NSW = 0
# Copying VASP files to VASP_Systems/c_4.999
# creating submit.sl for VASP_Systems/c_4.999
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.0
# creating submit.sl for VASP_Systems/c_5.0
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.1
# creating submit.sl for VASP_Systems/c_5.1
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.2
# creating submit.sl for VASP_Systems/c_5.2
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.3
# creating submit.sl for VASP_Systems/c_5.3
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.4
# creating submit.sl for VASP_Systems/c_5.4
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.5
# creating submit.sl for VASP_Systems/c_5.5
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.6
# creating submit.sl for VASP_Systems/c_5.6
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.7
# creating submit.sl for VASP_Systems/c_5.7
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.8
# creating submit.sl for VASP_Systems/c_5.8
# NSW = 0
# Copying VASP files to VASP_Systems/c_5.9
# creating submit.sl for VASP_Systems/c_5.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-98461d71ca64> in <module>
# ----> 1 LatticeFinder_Program(symbol, lattice_type, lattice_constant_parameters, calculator, size=size, directions=directions, miller=miller, no_of_cpus=no_of_cpus, limits=limits, make_svg_eps_files=make_svg_eps_files, slurm_information=slurm_information)
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/LatticeFinder.py in __init__(self, symbol, lattice_type, lattice_constant_parameters, calculator, size, directions, miller, limits, make_svg_eps_files, no_of_cpus, slurm_information)
#      26                 self.show_initial_messages(symbol, lattice_type, lattice_constant_parameters, calculator, size, directions, miller, limits, no_of_cpus, slurm_information)
#      27                 # Run the program
# ---> 28                 self.run()
#      29
#      30         def show_initial_messages(self, symbol, lattice_type, lattice_constant_parameters, calculator, size, directions, miller, limits, no_of_cpus, slurm_information):
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/LatticeFinder.py in run(self)
#     133                 energies_vs_lattice_constants = self.setup_energies_vs_lattice_constants()
#     134                 # Process the range of lattice constants and determine the minimum energy and lattice constant, as well as the projected lattice constant
# --> 135                 energies_vs_lattice_constants = self.get_data(energies_vs_lattice_constants)
#     136                 self.sort_data_file()
#     137                 energies_vs_lattice_constants, energy_vs_volumes = self.divide_up_energies_and_volumes(energies_vs_lattice_constants)
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/LatticeFinder.py in get_data(self, energies_vs_lattice_constants)
#     226                 print('Getting data')
#     227                 if self.calculator == 'vasp':
# --> 228                         energies_vs_lattice_constants = get_energies_across_lattice_constants_VASP(self.lattice_type,self.symbol,self.lattice_constant_generator,self.size,directions=self.directions,miller=self.miller,lattice_data_file=self.lattice_data_file,vasp_inputs=self.VASP_Input_files,folder_name=self.VASP_Systems_Folder,slurm_information=self.slurm_information,force_rewrite=False,lattice_type_name=self.lattice_type_name,make_packets=self.make_packets)
#     229                 elif self.calculator == 'manual mode':
#     230                         energies_vs_lattice_constants = get_energies_across_lattice_constants_in_Manual_Mode(self.lattice_type,self.symbol,self.lattice_constant_generator,self.size,self.directions,self.miller,self.Manual_Mode_Cluster_Folder)
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/examining_lattice_constant_methods_with_VASP.py in get_energies_across_lattice_constants_VASP(lattice_type, symbol, lattice_constant_generator, size, directions, miller, lattice_data_file, vasp_inputs, folder_name, slurm_information, force_rewrite, lattice_type_name, make_packets)
#      12         if force_rewrite or make_new_cell_folders(folder_name,lattice_constant_generator):
#      13                 print('Not getting data, instead making clusters for running in VASP.')
# ---> 14                 make_VASP_folders(lattice_type,symbol,lattice_constant_generator,size,directions,miller,vasp_inputs,folder_name,slurm_information,force_rewrite,make_packets)
#      15                 exit()
#      16         else:
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/examining_lattice_constant_methods_with_VASP.py in make_VASP_folders(lattice_type, symbol, lattice_constant_generator, size, directions, miller, vasp_inputs, folder_name, slurm_information, force_rewrite, make_packets)
#     125                         all_directories.append(name)
#     126         if make_packets == 'packets':
# --> 127                 make_packet_submitSL_files(folder_name,all_directories,slurm_information)
#     128
#     129 def check_VASP_files(vasp_files_folder):
#
# ~/Desktop/hgfs/GoogleDrive/PhDWork/Programs/LatticeFinder/LatticeFinder_v1.1.2.5/LatticeFinder/LatticeFinder/examining_lattice_constant_methods_with_VASP.py in make_packet_submitSL_files(root, all_directories, slurm_information)
#     181         # other stuff
#     182         number_of_vasp_calc_to_run_per_packet = slurm_information['Number of VASP calculations to run per packet']
# --> 183         make_submitSL_packets_for_latticeFinder(number_of_vasp_calc_to_run_per_packet,all_directories,root,project,time,nodes,ntasks_per_node,mem_per_cpu,partition=partition,email=email,python_version=python_version,vasp_version=vasp_version,vasp_execution=vasp_execution)
#     184
#     185
#
# TypeError: make_submitSL_packets_for_latticeFinder() missing 1 required positional argument: 'mem_per_cpu'

# %% [markdown]
# [Back To Table of Contents](../../LatticeFinder_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data

# %% [markdown]
# Once LatticeFinder is finished, it prints out a bunch of files. These include:
#
# * png files that shows the energy of the Au crystal structure across various lattice constants, and the optimal lattice constant for the Au FCC crystal structure.
# * ``lattice_data.txt`` that includes the energies of the FCC crystal for the various lattice constant values
# * ``results_file.txt`` that shows some of the various results from performing the LatticeFinder program, such as the cohesive energy.
#
# See the file explorer on the right of this jupyter lab webpage to take a look at them.
#
# Below is an example of the energy vs lattice constants plots for the Au FCC crystal structure.

# %%
from IPython.display import Image
Image(filename='Energy_Vs_Lattice_Constant.png')

# %% [markdown]
# [Back To Table of Contents](../../LatticeFinder_Jupyter_Example.ipynb)
